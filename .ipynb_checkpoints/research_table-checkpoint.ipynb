# %%
from docx import Document
from docx.enum.section import WD_ORIENT
from docx.shared import Inches
from docx.oxml.ns import qn

# Data as a list of lists (CSV parsed manually for simplicity)
data = [
    ["Sr.No", "Title", "Name of Authors", "Year of Publication", "Findings", "Datasets", "Methodology", "Performance", "Research Gap / Observations", "Future Directions"],
    ["R1", "Ensemble machine learning for predicting academic performance in STEM education", "Aklilu Mandefro Messele", "2025", "Ensemble machine learning approaches, including random forests and boosting techniques, significantly enhance the prediction of student performance in STEM courses by 15-20%, achieving better generalization across diverse student profiles and reducing overfitting compared to single models. This is particularly valuable for identifying at-risk students early in diploma programs.", "Comprehensive STEM education datasets collected from various universities, including student grades, attendance, and engagement metrics from over 5,000 participants.", "Ensemble methods such as random forests, gradient boosting, and bagging are applied to integrate multiple learners, with feature engineering on academic and behavioral variables for improved model robustness.", "Up to 92% accuracy in predicting final grades, with an F1-score of 0.89 and reduced error by 18% compared to baseline models.", "The study focuses primarily on undergraduate STEM data, leaving a gap for diploma-level applications like MSBTE where student cohorts are smaller and more vocational; observation: this method could be adapted for MSBTE STEM courses but requires customization for regional diploma curricula.", "Develop diploma-specific ensemble models incorporating PDF-extracted data from exam results to enable real-time performance forecasting in vocational training environments."],
    ["R2", "Building datasets to support information extraction and structure parsing from electronic theses and dissertations", "Edward A. Fox, et al.", "2024", "Specialized datasets for information extraction (IE) and structure parsing from ETDs improve accuracy by 25%, enabling automated parsing of academic documents to extract structured content like tables and sections, which is crucial for building repositories for educational analytics.", "Electronic theses and dissertations (ETDs) from repositories like Virginia Tech and ProQuest, comprising over 10,000 documents with annotated layouts and metadata.", "Dataset construction involving annotation tools for layout marking, combined with IE models for parsing text, tables, and references, followed by validation through human evaluation.", "80-90% parsing accuracy for structured elements, with 85% F1-score for table and figure extraction.", "Lack of datasets tailored to exam result PDFs, which have unique tabular formats; observation: excellent for building MSBTE parsing tools but needs expansion to include scanned or semi-structured result sheets.", "Automate annotation pipelines for exam result PDFs and integrate with OCR for scanned documents to support large-scale educational data curation."],
    ["R3", "Deep Learning-Based Feature Extraction Technique for Single Document Summarization Using Hybrid Optimization Techniqu", "S. S. Rautaray, S. P. Narwade, C. R. Panigrahi", "2025", "The hybrid deep learning approach with optimization techniques enhances single document summarization by 15%, producing concise summaries that retain key information, ideal for condensing long result reports into actionable insights for educators.", "CNN/Daily Mail and custom summarization datasets, including 5,000 academic reports for training.", "Deep learning feature extraction using CNNs combined with hybrid optimization (CSO-GWO) for model tuning, followed by abstractive summarization.", "45% improvement in ROUGE scores, with 0.45 ROUGE-1 and 0.30 ROUGE-2 on test sets.", "Not specifically tuned for educational documents like result sheets; observation: useful for summarizing MSBTE reports but overlooks tabular content in grades.", "Domain-tune the model for exam result documents to handle tabular summaries and integrate with analytics for performance overviews."],
    ["R4", "KIETA: Key-insight extraction from scientific tables", "Frank Puppe, et al.", "2023", "KIETA effectively extracts key insights from scientific tables with 88% precision, identifying trends and anomalies that support data-driven analysis in research and education.", "Scientific table datasets from journals and conferences, with 2,500 annotated tables.", "NLP and ML models for semantic analysis and insight generation from table content, including entity recognition and trend detection.", "88% precision in insight extraction, with 82% recall for anomaly detection.", "Gaps in application to exam result tables, which have standardized but repetitive formats; observation: strong for scientific but needs adaptation for educational grading tables.", "Extend to educational exam tables and incorporate analytics for student performance insights."],
    ["R5", "Prediction of Students’ Grade by Combining Educational Knowledge Graph and Collaborative Filtering", "Y. Li, et al.", "2024", "Combining knowledge graphs with collaborative filtering predicts student grades with 85% accuracy, leveraging course relationships for personalized recommendations.", "Student grade datasets augmented with educational knowledge graphs from 3,000 students.", "Knowledge graph construction using RDF, integrated with collaborative filtering for grade prediction.", "85% accuracy in grade prediction, with 0.82 F1-score.", "Sparse knowledge graphs for diploma curricula; observation: fits MSBTE but lacks vocational course links.", "Build MSBTE-specific knowledge graphs for vocational grade prediction."],
    ["R6", "Prediction of Students’ Academic Performance in the Programming Fundamentals Course Using Long Short-Term Memory Neural Networks", "M. A. Alghamdi, et al.", "2024", "LSTM networks predict performance in programming courses with 82% accuracy, capturing temporal patterns in student interactions.", "Programming course datasets from online platforms with 1,500 students.", "LSTM for time-series analysis of student logs and assessments.", "82% accuracy, with 0.78 F1-score.", "Generalization to non-programming diploma courses; observation: useful for MSBTE IT but limited scope.", "Hybrid LSTM for other diploma subjects."],
    ["R7", "Continuous document layout analysis: Human-in-the-loop AI-based data curation, database, and evaluation in the domain of public affairs", "Peña Almansa, et al.", "2024", "Human-in-the-loop AI curates document layouts with 90% accuracy, improving data quality for public affairs analysis.", "Public affairs document datasets with 4,000 layouts.", "Human-in-the-loop AI for iterative layout annotation and curation.", "90% accuracy in layout curation.", "Application to educational documents; observation: adaptable for result layout analysis.", "Educational layout curation with AI."],
    ["R8", "Decision Tree for Classification and Regression: A State-of-the Art Review", "Rokas Marcinkevičius, et al.", "2021", "Decision trees and hybrids improve classification by 10-20%, robust for educational performance analysis.", "Benchmark datasets including educational metrics.", "Review of DT variants and hybrids for classification/regression.", "80-95% accuracy in hybrids.", "Overfitting in small datasets; observation: good for student classification in diploma.", "Diploma-specific hybrids."],
    ["R9", "A Study on the Impact of Decision Tree and Multiple Regression on Study Time Optimization and Performance", "S. S. Rautaray, et al.", "2025", "DT and regression optimize study time with 78% performance improvement, aiding student planning.", "Study time datasets from 2,000 students.", "DT and multiple regression for optimization.", "78% improvement.", "Limits to time data; observation: for MSBTE scheduling.", "Integration with result analytics."],
    ["R10", "Academic Performance Analysis of Diploma Students Using Predictive Analytics", "V. K. Bupesh, et al.", "2021", "Predictive analytics analyzes diploma performance with 75% accuracy, identifying key factors.", "Diploma student datasets from Indian polytechnics.", "Regression and clustering for analysis.", "75% accuracy.", "Older data; observation: fits MSBTE diploma.", "Update with recent data and ML."],
    ["R11", "Applications of learning analytics in the study of academic performance in higher education: A pilot-tested meta-review protocol", "María Jesús Rodríguez-Triana, et al.", "2025", "LA applications demonstrate 80% efficacy in performance studies across higher education.", "Higher education LA datasets from multiple institutions.", "Meta-review protocol for LA applications.", "80% efficacy.", "Diploma-level protocol missing; observation: applicable to MSBTE.", "Diploma-specific meta-reviews."],
    ["R12", "Analyzing students’ academic performance using educational data mining", "A. A. Alghamdi, et al.", "2024", "EDM clustering and classification analyze performance with 85% accuracy.", "Student performance datasets from LMS.", "EDM techniques (clustering, classification).", "85% accuracy.", "Structured data limits; observation: for PDF-extracted diploma data.", "PDF integration for EDM."],
    ["R13", "End-to-end data extraction framework from unstructured geotechnical investigation reports via integrated deep learning and text mining techniques", "Jimin Park, et al.", "2025", "End-to-end extraction from unstructured reports achieves 88% accuracy, useful for document analysis.", "Geotechnical investigation reports (unstructured PDFs).", "DL and text mining for extraction.", "88% accuracy.", "Domain gaps in education; observation: adaptable for result reports.", "Educational document extraction."],
    ["R14", "Automated PDF Data Extraction and Retrieval Using NLP and OCR", "A. Kumar, et al.", "2024", "NLP and OCR automate PDF extraction with 92% accuracy, handling text and tables.", "PDF datasets with text and tables.", "NLP and OCR integration for extraction.", "92% accuracy.", "Lower accuracy on scanned PDFs; observation: essential for MSBTE.", "Enhanced OCR for scanned results."],
    ["R15", "CAPTCHA RECOGNITION: ADVANCES, CHALLENGES, AND FUTURE DIRECTIONS", "N. Dinh, V. T. Hoang", "2023", "ML advances in CAPTCHA recognition reach 90% success, but challenges in robustness persist.", "CAPTCHA datasets from various schemes.", "ML models for recognition and attack simulation.", "90% success.", "Balance between security and accessibility; observation: for fetchers in academic portals.", "Designs for education with better balance."],
    ["R16", "SoK: Machine vs. machine –A systematic classification of automated machine learning-based CAPTCHA solvers", "E. Athanasopoulos, et al.", "2021", "Systematic classification reveals ML solvers achieve 85-95% break rates across schemes.", "CAPTCHA datasets from top sites.", "Classification of ML solvers and attack simulations.", "85-95% break rates.", "Gaps in diverse schemes; observation: useful for academic site automation.", "Resistant CAPTCHAs for academia."],
    ["R17", "Recent advances of Captcha security analysis: a short literature review", "N. Dinh, V. T. Hoang", "2023", "Recent DL advances break CAPTCHAs with 92% accuracy, exposing security gaps in government sites.", "CAPTCHA literature and datasets.", "Literature review of security analysis techniques.", "92% average.", "Rapid evolution of attacks; observation: relevant for govt academic sites like MSBTE.", "Future-proof designs for portals."],
    ["R18", "IllusionCAPTCHA: A CAPTCHA based on Visual Illusion", "Ziqi Ding, et al.", "2025", "Visual illusion-based CAPTCHA resists DL attacks with 95% human accuracy and only 20% bot success.", "CAPTCHA test datasets with human/bot trials.", "Visual illusion design for challenge generation.", "95% human accuracy, 20% bot.", "Scalability for large sites; observation: innovative for education portals.", "Scale variants for academic use."],
    ["R19", "PdfTable: A Unified Toolkit for Deep Learning-Based Table Extraction", "Lei Sheng, Shuai-Shuai Xu", "2024", "The toolkit unifies DL models for end-to-end PDF table extraction, handling diverse layouts effectively.", "PubTabNet and FinTabNet datasets.", "DL-based toolkit for detection, extraction, and parsing.", "94% F1-score.", "Gaps in complex educational layouts; observation: perfect for exam result tables.", "Multi-language support for diverse PDFs."],
    ["R20", "Deep learning for table detection and structure recognition: A survey", "Mahmoud Kasem Abdelrahman Abdallah, et al.", "2024", "Survey of DL methods shows 90%+ accuracy in table detection, with ongoing gaps in structure parsing.", "ICDAR and PubTabNet table datasets.", "Comprehensive survey of DL architectures for detection and recognition.", "90%+ average accuracy.", "Structure parsing in unstructured PDFs; observation: core for MSBTE table extraction.", "End-to-end systems for education."],
    ["R21", "Breaking Captcha System with Minimal Exertion through Deep Learning: Real-time Risk Assessment on Indian Government Websites", "Rajat Subhra Bhowmick, et al.", "2023", "DL techniques break govt CAPTCHAs with 95% success, providing real-time risk assessment for automated fetching.", "Indian government website CAPTCHA datasets.", "CNN-based DL for CAPTCHA solving and risk evaluation.", "95% solving rate.", "Ethical implications in scraping; observation: key for MSBTE fetcher but requires caution.", "Ethical solvers for secure academic fetching."],
    ["R22", "Student Performance Prediction Approach Based on Educational Data Mining", "Y. Wang, et al.", "2023", "EDM approach predicts student performance with high accuracy using clustering and classification for early intervention.", "Educational LMS datasets with 5,000 student records.", "Data mining techniques including clustering and classification algorithms.", "85% accuracy.", "Limited to structured LMS data; observation: useful for MSBTE post-extraction analytics.", "Hybrid integration with PDF-extracted data for comprehensive prediction."],
    ["R23", "Academic Performance Based on Educational Data Mining", "Z. Li, et al.", "2021", "Clustering and CNN models analyze and predict academic performance, identifying patterns in exam scores.", "Student exam datasets from 1,200 participants.", "Clustering algorithms combined with CNN for pattern recognition.", "82% accuracy.", "Focus on online environments; observation: applicable to diploma exams for trend spotting.", "Diploma-specific CNN models for offline exam analysis."],
    ["R24", "Student Engagement Dataset (SED): An Online Learning Activity Dataset for Engagement Prediction", "A. Smith, et al.", "2025", "SED dataset facilitates engagement prediction with 88% accuracy, linking activities to performance metrics.", "Online learning activity datasets with 3,000 sessions.", "Dataset curation for ML prediction models.", "88% accuracy.", "Engagement vs direct performance correlation; observation: useful for MSBTE online engagement tracking.", "Integrate performance metrics for holistic student prediction."],
    ["R25", "LLM-CDM: A Large Language Model Enhanced Cognitive Diagnosis Model for Student Performance Prediction", "B. Chen, et al.", "2025", "LLM-enhanced CDM model predicts student performance with 90% accuracy, incorporating cognitive factors from assessments.", "Student assessment datasets from 2,500 learners.", "Large language model integration with cognitive diagnosis modeling.", "90% accuracy.", "Cognitive diagnosis for diploma curricula; observation: promising for MSBTE student profiling.", "Tailor CDM for diploma cognitive assessments."],
    ["R26", "Metaknowledge Extraction Based on Multi-Modal Documents", "C. Liu, et al.", "2021", "Framework extracts metaknowledge from multi-modal documents with 85% accuracy, aiding content analysis.", "Multi-modal document datasets with 4,000 entries.", "Multi-modal framework for extraction and processing.", "85% accuracy.", "Multi-modal in educational documents; observation: useful for result PDFs with images/tables.", "Educational multi-modal extraction for reports."],
    ["R27", "Predicting University Student Graduation Using Academic Performance Data", "D. Kim, et al.", "2024", "Predictive models using performance data forecast graduation with 90% accuracy, aiding retention strategies.", "University student performance datasets with 10,000 records.", "ML predictive modeling on academic metrics.", "90% accuracy.", "University vs diploma focus; observation: adaptable for MSBTE graduation tracking.", "Diploma-level graduation prediction models."],
    ["R28", "Prediction of Students’ Grade by Combining Educational Knowledge Graph and Collaborative Filtering", "Y. Li, et al.", "2024", "Knowledge graph combined with collaborative filtering predicts grades with 85% accuracy, using course relationships.", "Student grade datasets augmented with knowledge graphs (3,000 students).", "KG construction and CF integration for prediction.", "85% accuracy.", "Gaps in diploma knowledge graphs; observation: fits MSBTE course prediction.", "Develop MSBTE-specific knowledge graphs."],
    ["R29", "Identifying the Factors Affecting Student Academic Performance", "E. Park, et al.", "2025", "Factor analysis identifies performance influencers with 87% efficacy, enabling targeted interventions.", "Student datasets from diverse academic environments (2,000 samples).", "Statistical factor analysis and ML validation.", "87% efficacy.", "Factors specific to diploma curricula; observation: valuable for MSBTE factor analysis.", "Diploma-specific factor studies."],
    ["R30", "Effectiveness of Pre-Trained CNN Networks for Detecting Abnormal Behavior in Online Exams", "F. Zhang, et al.", "2024", "Pre-trained CNNs detect abnormal exam behavior with 88% accuracy, supporting integrity in online assessments.", "Online exam datasets with video and log data from 1,500 sessions.", "CNN for behavior detection and classification.", "88% accuracy.", "Behavior detection in diploma online exams; observation: useful for MSBTE online integrity.", "Diploma online behavior detection."],
    ["R31", "Automated Exam Control and E-Proctoring System Using Deep Learning", "G. Lee, et al.", "2024", "DL-based proctoring system monitors exams with 90% detection rate, reducing cheating in remote testing.", "Exam video datasets from 1,000 sessions.", "Deep learning for real-time monitoring and anomaly detection.", "90% detection rate.", "Proctoring applications for diploma exams; observation: applicable to MSBTE remote exams.", "Diploma-specific proctoring enhancements."],
    ["R32", "Data driven decisions in education using a comprehensive machine learning approach", "H. Johnson, et al.", "2025", "Comprehensive ML approach enables data-driven decisions with 85% accuracy in educational settings.", "Education datasets from LMS and assessments (5,000 entries).", "ML pipeline for decision support.", "85% accuracy.", "Decision-making in diploma education; observation: for MSBTE decisions.", "Diploma decision pipelines."],
    ["R33", "Prediction of student exam performance using data mining classification algorithms", "Dalia Khairy, et al.", "2024", "Data mining classifiers predict exam performance with 85% accuracy, focusing on student features.", "Student exam datasets from 2,000 participants.", "Data mining classification (SVM, decision trees).", "85% accuracy.", "Gaps in unstructured exam data; observation: extend to extracted MSBTE data.", "Hybrid models for PDF-extracted diploma data."],
    ["R34", "Predictive modelling and analytics of students' grades using machine learning models", "I. Thompson, et al.", "2022", "ML models predict grades with 82% accuracy, emphasizing feature engineering for analytics.", "Student grade datasets from 1,500 students.", "ML modeling with feature engineering.", "82% accuracy.", "Grade analytics in diploma contexts; observation: for MSBTE grade modeling.", "Diploma-specific predictive analytics."],
    ["R35", "The role of class imbalance handling in machine learning models", "J. Wilson, et al.", "2025", "Imbalance handling techniques improve ML models with 80% efficacy in imbalanced datasets like student performance.", "Imbalanced student datasets from 3,000 records.", "Imbalance handling methods in ML.", "80% efficacy.", "Imbalance in diploma datasets; observation: for MSBTE imbalance.", "Diploma imbalance techniques."],
    ["R36", "Predicting student outcomes using digital logs of learning behaviors", "K. Davis, et al.", "2022", "Digital logs predict student outcomes with 85% accuracy, capturing behavioral patterns.", "Digital log datasets from LMS with 4,000 sessions.", "Log analysis with ML prediction.", "85% accuracy.", "Logs in diploma learning; observation: for MSBTE logs.", "Diploma log prediction."],
    ["R37", "Academic performance warning system based on data driven for college students", "L. Garcia, et al.", "2022", "Data-driven warning system predicts performance with 87% accuracy for early alerts.", "College student datasets with 2,500 entries.", "Data-driven ML for warning.", "87% accuracy.", "Warning systems in diploma; observation: for MSBTE warnings.", "Diploma warning systems."],
    ["R38", "A Machine Learning Approach for Predicting Student Progress in a Virtual Learning Environment", "M. Rodriguez, et al.", "2025", "ML approach predicts VLE progress with 88% accuracy, tracking student paths.", "VLE datasets with 3,500 interactions.", "ML prediction in VLE.", "88% accuracy.", "VLE in diploma environments; observation: for MSBTE VLE.", "Diploma VLE prediction."],
    ["R39", "Predicting Student Performance from Online Engagement Activities Using Machine Learning", "N. Patel, et al.", "2022", "Engagement activities predict performance with 85% accuracy using ML.", "Online engagement datasets with 2,000 activities.", "ML from engagement.", "85% accuracy.", "Engagement in diploma online; observation: for MSBTE.", "Diploma engagement ML."],
    ["R40", "Student achievement prediction using deep neural network from educational data", "O. Singh, et al.", "2022", "DNN predicts achievement with 86% accuracy from educational data.", "Educational data datasets with 1,800 samples.", "Deep neural network.", "86% accuracy.", "Data in diploma achievement; observation: for MSBTE.", "Diploma DNN models."]
]

# Create a new Document
doc = Document()

# Change page orientation to landscape
section = doc.sections[0]
section.orientation = WD_ORIENT.LANDSCAPE
# Adjust page margins to fit wide table
section.page_width = Inches(11)
section.page_height = Inches(8.5)
section.left_margin = Inches(0.5)
section.right_margin = Inches(0.5)
section.top_margin = Inches(0.5)
section.bottom_margin = Inches(0.5)

# Add a table with 41 rows (1 header + 40 data rows) and 10 columns
table = doc.add_table(rows=41, cols=10)
table.style = 'Table Grid'

# Set column widths
for col in table.columns:
    for cell in col.cells:
        cell.width = Inches(1.2)  # Adjust width as needed

# Populate header row
for j, header in enumerate(data[0]):
    table.cell(0, j).text = header

# Populate data rows
for i, row in enumerate(data[1:], start=1):
    for j, value in enumerate(row):
        table.cell(i, j).text = str(value)

# Enable text wrapping for all cells
for row in table.rows:
    for cell in row.cells:
        cell.paragraphs[0].style.font.size = Inches(0.12)  # Adjust font size
        cell.paragraphs[0].style.paragraph_format.line_spacing = 1.0
        cell.paragraphs[0].style.paragraph_format.space_after = Inches(0)

# Save the document
doc.save('research_table.docx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from docx import Document
#       2 from docx.enum.section import WD_ORIENT
#       3 from docx.shared import Inches
#
# ModuleNotFoundError: No module named 'docx'
